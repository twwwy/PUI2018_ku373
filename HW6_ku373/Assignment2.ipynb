# %% [markdown]
# # SQL CARTO QUERY FUNCTION
# # written for PUI2016_Python2

# %% [markdown]
# ##### This notebook is set up to link as a default to the fb55 account.  To turn in the homework use the citibike dataset - check that you are able to read in about 40k rows

# %%
SQL_SOURCE = 'https://fb55.carto.com/api/v2/sql?q='

import urllib2
import urllib
import StringIO
import ast
import pandas as pd
try:
    from StringIO import BytesIO as io
except ImportError:
    from io import BytesIO as io


def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urllib.urlencode({'format': format, 'q': query})
    try:
        response = urllib2.urlopen(source, data)
    except urllib2.HTTPError, e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return response.read()

def get_data(query):
    try:
        return pd.read_csv(io(queryCartoDB(query)), sep = ',')
    except ValueError as v:
        print (str(v))

# %%
test = '''
SELECT *
FROM fb55.citibike
'''
table = get_data(test)
table.head()

#FROM citibike_short
# Out:
#    the_geom  start_station_name  the_geom_webmercator  field_1  \
# 0       NaN  E 20 St & Park Ave                   NaN      175
# 1       NaN    W 43 St & 10 Ave                   NaN     1159
# 2       NaN   E 6 St & Avenue B                   NaN     2827
# 3       NaN     E 12 St & 3 Ave                   NaN     4961
# 4       NaN     W 41 St & 8 Ave                   NaN     6156
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.987520          1090  2015-02-01 01:23:00+00
# 1               -73.994618           682  2015-02-01 10:55:00+00
# 2               -73.981854           751  2015-02-01 13:59:00+00
# 3               -73.988900           272  2015-02-01 17:28:00+00
# 4               -73.990026           240  2015-02-01 21:36:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 01:42:00+00               503         107
# 1  2015-02-01 11:07:00+00               515        1088
# ...

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(test)), sep=',')
# Out:
#        the_geom        start_station_name  the_geom_webmercator  field_1  \
# 0           NaN        E 20 St & Park Ave                   NaN      175
# 1           NaN          W 43 St & 10 Ave                   NaN     1159
# 2           NaN         E 6 St & Avenue B                   NaN     2827
# 3           NaN           E 12 St & 3 Ave                   NaN     4961
# 4           NaN           W 41 St & 8 Ave                   NaN     6156
# 5           NaN           5 Ave & E 29 St                   NaN     7433
# 6           NaN      Allen St & Hester St                   NaN     7779
# 7           NaN           E 39 St & 3 Ave                   NaN     8327
# 8           NaN          10 Ave & W 28 St                   NaN     9435
# 9           NaN            E 2 St & 2 Ave                   NaN    10472
# 10          NaN           1 Ave & E 44 St                   NaN    10931
# 11          NaN           W 45 St & 6 Ave                   NaN    11361
# ...

# %%
# Task1
query = '''
SELECT *
FROM fb55.citibike
where tripduration <= 360
;
'''

table = get_data(query)
table.head(5)
# Out:
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN    E 12 St & 3 Ave                   NaN     4961
# 1       NaN    W 41 St & 8 Ave                   NaN     6156
# 2       NaN    5 Ave & E 29 St                   NaN    13365
# 3       NaN    E 39 St & 2 Ave                   NaN    13750
# 4       NaN   10 Ave & W 28 St                   NaN    14218
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.988900           272  2015-02-01 17:28:00+00
# 1               -73.990026           240  2015-02-01 21:36:00+00
# 2               -73.986831           319  2015-02-04 07:35:00+00
# 3               -73.973442           358  2015-02-04 08:11:00+00
# 4               -74.001768           338  2015-02-04 08:45:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 17:32:00+00               483        4893
# 1  2015-02-01 21:40:00+00               477        6090
# ...

# %%
query1 = '''
SELECT *
FROM fb55.citibike
where tripduration <= 360
ORDER BY start_station_id ASC, tripduration ASC
LIMIT 10;
'''

table1 = get_data(query1)
table1.head(10)
# Out:
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN   W 52 St & 11 Ave                   NaN     9059
# 1       NaN   W 52 St & 11 Ave                   NaN    40772
# 2       NaN   W 52 St & 11 Ave                   NaN    40770
# 3       NaN   W 52 St & 11 Ave                   NaN    22002
# 4       NaN   W 52 St & 11 Ave                   NaN    43107
# 5       NaN   W 52 St & 11 Ave                   NaN    32603
# 6       NaN   W 52 St & 11 Ave                   NaN    16015
# 7       NaN   W 52 St & 11 Ave                   NaN    41366
# 8       NaN   W 52 St & 11 Ave                   NaN    42084
# 9       NaN   W 52 St & 11 Ave                   NaN     2348
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.993929           107  2015-02-03 10:10:00+00
# 1               -73.993929           189  2015-02-07 10:40:00+00
# 2               -73.993929           229  2015-02-07 10:40:00+00
# ...

# %%
query = '''
SELECT *
FROM fb55.citibike
where tripduration <= 360
ORDER BY start_station_id DESC, tripduration DESC
LIMIT 10;
'''
table = get_data(query)
table.head(10)
# Out:
#    the_geom          start_station_name  the_geom_webmercator  field_1  \
# 0       NaN  South End Ave & Liberty St                   NaN    32540
# 1       NaN  South End Ave & Liberty St                   NaN     8530
# 2       NaN  South End Ave & Liberty St                   NaN    14104
# 3       NaN  South End Ave & Liberty St                   NaN    38330
# 4       NaN  South End Ave & Liberty St                   NaN    38931
# 5       NaN  South End Ave & Liberty St                   NaN     4621
# 6       NaN  South End Ave & Liberty St                   NaN     7744
# 7       NaN  South End Ave & Liberty St                   NaN    13343
# 8       NaN  South End Ave & Liberty St                   NaN    46022
# 9       NaN  South End Ave & Liberty St                   NaN    35556
#
#    start_station_longitude  tripduration               starttime  \
# 0               -74.015756           358  2015-02-06 08:54:00+00
# ...

# %%
query = '''
SELECT DISTINCT start_station_id FROM fb55.citibike
ORDER BY start_station_id ASC
;
'''
table = get_data(query); table
# Out:
#      start_station_id  Unnamed: 1
# 0                  72         NaN
# 1                  79         NaN
# 2                  82         NaN
# 3                  83         NaN
# 4                 116         NaN
# 5                 119         NaN
# 6                 120         NaN
# 7                 127         NaN
# 8                 128         NaN
# 9                 137         NaN
# 10                143         NaN
# 11                144         NaN
# 12                146         NaN
# 13                147         NaN
# 14                150         NaN
# 15                151         NaN
# 16                152         NaN
# 17                153         NaN
# 18                157         NaN
# 19                160         NaN
# 20                161         NaN
# 21                164         NaN
# 22                167         NaN
# 23                168         NaN
# 24                173         NaN
# 25                174         NaN
# ...

# %%
query = '''
SELECT COUNT(*) FROM fb55.citibike;
'''
table = get_data(query); table
# Out:
#    count  Unnamed: 1
# 0  46200         NaN

# %%
query = '''
SELECT AVG(tripduration), MAX(tripduration) , MIN(tripduration)FROM fb55.citibike
;
'''
table = get_data(query); table
# Out:
#           avg    max  min
# 0  675.865823  43016   60

# %% [markdown]
# # TASK 2

# %%
query = '''
SELECT *
FROM fb55.citibike
WHERE EXTRACT(YEAR FROM starttime) = 2015 and EXTRACT(MONTH FROM starttime) = 2 
and EXTRACT(DAY FROM starttime) = 2 
;
'''
table = get_data(query)
table.head(10)
# Out:
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN       5 Ave & E 29 St                   NaN     7433
# 1       NaN  Allen St & Hester St                   NaN     7779
# 2       NaN     E 5 St & Avenue C                   NaN       11
# 3       NaN       9 Ave & W 16 St                   NaN      627
# 4       NaN       9 Ave & W 16 St                   NaN      991
# 5       NaN       W 33 St & 7 Ave                   NaN     1037
# 6       NaN       W 27 St & 7 Ave                   NaN     6510
# 7       NaN       E 11 St & 1 Ave                   NaN     6511
# 8       NaN  Peck Slip & Front St                   NaN     6512
# 9       NaN       E 16 St & 5 Ave                   NaN     6513
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.986831           376  2015-02-02 17:44:00+00
# 1               -73.991908          1217  2015-02-02 20:12:00+00
# ...

# %%
query = '''
SELECT DATEPART(weekday, starttime) FROM fb55.citibike

;
'''
table = get_data(query)
table.head(10)
# Out:
# column "weekday" does not exist
# AttributeErrorTraceback (most recent call last)
# <ipython-input-147-ae558df66179> in <module>()
#       5 '''
#       6 table = get_data(query)
# ----> 7 table.head(10)
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
query = '''
SELECT DATEPART(dw,GETDATE())
'''
table = get_data(query)
table.head(10)

# %% [markdown]
# # TASK 3

# %%
query = '''
SELECT DISTINCT start_station_name
FROM fb55.citibike
GROUP BY start_station_name
;
'''
table = get_data(query)
table
# Out:
#                 start_station_name  Unnamed: 1
# 0                 10 Ave & W 28 St         NaN
# 1                 11 Ave & W 27 St         NaN
# 2                 11 Ave & W 41 St         NaN
# 3                 11 Ave & W 59 St         NaN
# 4                 12 Ave & W 40 St         NaN
# 5                  1 Ave & E 15 St         NaN
# 6                  1 Ave & E 44 St         NaN
# 7                  2 Ave & E 31 St         NaN
# 8                  2 Ave & E 58 St         NaN
# 9          3 Ave & Schermerhorn St         NaN
# 10                 5 Ave & E 29 St         NaN
# 11               6 Ave & Broome St         NaN
# 12                6 Ave & Canal St         NaN
# 13                 6 Ave & W 33 St         NaN
# 14                 8 Ave & W 31 St         NaN
# 15                 8 Ave & W 33 St         NaN
# 16                 8 Ave & W 52 St         NaN
# 17                 9 Ave & W 14 St         NaN
# 18                 9 Ave & W 16 St         NaN
# ...

# %%
query = '''
SELECT start_station_name, COUNT(start_station_id) as count
FROM fb55.citibike
GROUP BY start_station_name
;
'''
table = get_data(query)
table
# Out:
#                 start_station_name  count
# 0             E 30 St & Park Ave S    227
# 1          Pearl St & Anchorage Pl     54
# 2                  W 56 St & 6 Ave    164
# 3                   West Thames St    107
# 4          Bank St & Washington St    125
# 5                  8 Ave & W 52 St    133
# 6               E 11 St & Broadway    115
# 7         DeKalb Ave & Skillman St     10
# 8    Atlantic Ave & Fort Greene Pl     36
# 9                Avenue D & E 8 St     38
# 10            S 3 St & Bedford Ave     13
# 11          W Broadway & Spring St    159
# 12                 2 Ave & E 31 St    302
# 13                 E 33 St & 5 Ave    213
# 14        MacDougal St & Prince St    247
# 15    Clermont Ave & Lafayette Ave     25
# 16          Barclay St & Church St    244
# 17          Forsyth St & Broome St    212
# 18                 W 13 St & 6 Ave    257
# 19                 W 17 St & 8 Ave    288
# 20              E 20 St & Park Ave    218
# ...

# %% [markdown]
# # TASK4

# %%
query = '''
SELECT *
FROM fb55.citibike
WHERE EXTRACT(HOUR FROM starttime::time) = 1
ORDER BY start_station_id DESC, tripduration DESC
LIMIT 10;
'''
table = get_data(query)
table.head(10)

# %% [markdown]
# # extra credit: make the function python 2 and 3 compatible so that it works on the  PUI2016_Python3 kernel
